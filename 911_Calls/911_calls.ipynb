# %% [markdown]
# **Analysis of 911 calls**
# and practicing basic numpy / pandas / matplotlib / seaborn

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# for seaborn defaults:
sns.set()

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../simple_data_application/911_Calls"))

# Any results you write to the current directory are saved as output.
# Out:
# ['911.csv', '911_calls.ipynb']

# %%
# read the csv containing the data
df = pd.read_csv("../simple_data_application/911_Calls/911.csv")
# check the file and data format
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326425 entries, 0 to 326424
# Data columns (total 9 columns):
# lat          326425 non-null float64
# lng          326425 non-null float64
# desc         326425 non-null object
# zip          286835 non-null float64
# title        326425 non-null object
# timeStamp    326425 non-null object
# twp          326310 non-null object
# addr         326425 non-null object
# e            326425 non-null int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 22.4+ MB

# %%
# check the data table
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>lat</th>
#       <th>lng</th>
#       <th>desc</th>
#       <th>zip</th>
#       <th>title</th>
#       <th>timeStamp</th>
#       <th>twp</th>
#       <th>addr</th>
#       <th>e</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>40.297876</td>
#       <td>-75.581294</td>
#       <td>REINDEER CT &amp; DEAD END;  NEW HANOVER; Station ...</td>
#       <td>19525.0</td>
#       <td>EMS: BACK PAINS/INJURY</td>
#       <td>2015-12-10 17:10:52</td>
#       <td>NEW HANOVER</td>
#       <td>REINDEER CT &amp; DEAD END</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %%
# get the top 5 zip code
df['zip'].value_counts().head()
# Out:
# 19401.0    22136
# 19464.0    21588
# 19403.0    16488
# 19446.0    15793
# 19406.0    10800
# Name: zip, dtype: int64

# %%
# get the top 5 townships for 911 calls
df['twp'].value_counts().head()
# Out:
# LOWER MERION    28073
# ABINGTON        20206
# NORRISTOWN      18433
# UPPER MERION    17276
# CHELTENHAM      15026
# Name: twp, dtype: int64

# %%
# count the unique title codes
# len(df['title'].unique()) or ...
df['title'].nunique()
# Out:
# 133

# %%
# from title column get the reason part and add as new column
df['reason'] = df['title'].apply(lambda x : x.split(':')[0])
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>lat</th>
#       <th>lng</th>
#       <th>desc</th>
#       <th>zip</th>
#       <th>title</th>
#       <th>timeStamp</th>
#       <th>twp</th>
#       <th>addr</th>
#       <th>e</th>
#       <th>reason</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>40.297876</td>
#       <td>-75.581294</td>
#       <td>REINDEER CT &amp; DEAD END;  NEW HANOVER; Station ...</td>
#       <td>19525.0</td>
#       <td>EMS: BACK PAINS/INJURY</td>
#       <td>2015-12-10 17:10:52</td>
#       <td>NEW HANOVER</td>
#       <td>REINDEER CT &amp; DEAD END</td>
#       <td>1</td>
#       <td>EMS</td>
# ...

# %%
# What is the most common reason? Show the reason counts!
df['reason'].value_counts()
# Out:
# EMS        161441
# Traffic    116065
# Fire        48919
# Name: reason, dtype: int64

# %%
sns.countplot(x='reason',data=df)

# %%
# get the datatypes of objects in timeStamp column
type(df['timeStamp'].iloc[0])
# Out:
# str

# %%
# cast the time object to DateTime object
df['timeStamp'] = pd.to_datetime(df['timeStamp'])
type(df['timeStamp'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# create new columns from timeStamp: hour, month, dayofweek
df['month'] = df['timeStamp'].apply(lambda x : x.month)
df['dayofweek'] = df['timeStamp'].apply(lambda x : x.dayofweek)
df['hour'] = df['timeStamp'].apply(lambda x : x.hour)

# %%
# use map() method with the dictionary 'dmap' to change the 0-6 to day names
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
df['dayofweek'] = df['dayofweek'].map(dmap)
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>lat</th>
#       <th>lng</th>
#       <th>desc</th>
#       <th>zip</th>
#       <th>title</th>
#       <th>timeStamp</th>
#       <th>twp</th>
#       <th>addr</th>
#       <th>e</th>
#       <th>reason</th>
#       <th>month</th>
#       <th>dayofweek</th>
#       <th>hour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>40.297876</td>
#       <td>-75.581294</td>
#       <td>REINDEER CT &amp; DEAD END;  NEW HANOVER; Station ...</td>
#       <td>19525.0</td>
#       <td>EMS: BACK PAINS/INJURY</td>
#       <td>2015-12-10 17:10:52</td>
#       <td>NEW HANOVER</td>
# ...

# %%
# countplot: week, hue: reason
sns.countplot(x=df['dayofweek'], hue=df['reason'])

# %%
# countplot: month, hue: reason
sns.countplot(x=df['month'], hue=df['reason'])

# %%
byMonth = df.groupby('month').count()
byMonth
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>lat</th>
#       <th>lng</th>
#       <th>desc</th>
#       <th>zip</th>
#       <th>title</th>
#       <th>timeStamp</th>
#       <th>twp</th>
#       <th>addr</th>
#       <th>e</th>
#       <th>reason</th>
#       <th>dayofweek</th>
#       <th>hour</th>
#     </tr>
#     <tr>
#       <th>month</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>37824</td>
# ...

# %%
byMonth['lat'].plot()

# %%
# linear fit on calls per month - not too useful
sns.lmplot(x='month', y='e', data=byMonth.reset_index())

# %%
# add new 'date' column
df['date'] = df['timeStamp'].apply(lambda x : x.date())
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>lat</th>
#       <th>lng</th>
#       <th>desc</th>
#       <th>zip</th>
#       <th>title</th>
#       <th>timeStamp</th>
#       <th>twp</th>
#       <th>addr</th>
#       <th>e</th>
#       <th>reason</th>
#       <th>month</th>
#       <th>dayofweek</th>
#       <th>hour</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>40.297876</td>
#       <td>-75.581294</td>
#       <td>REINDEER CT &amp; DEAD END;  NEW HANOVER; Station ...</td>
#       <td>19525.0</td>
#       <td>EMS: BACK PAINS/INJURY</td>
#       <td>2015-12-10 17:10:52</td>
# ...

# %%
# count calls per day and plot it
count_by_day = df.groupby('date').count()['e']
count_by_day.plot()

# %%
# count 'EMS' calls per day and plot it
df[df['reason']=='EMS'].groupby('date').count()['e']
count_by_day.plot()

# %%
# Count the calls by 'dayofweek' and 'hour' (at the and could choose any column)
day_hour = df.groupby(by=['dayofweek','hour']).count().unstack(level=-1)['e']
day_hour
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>hour</th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>...</th>
#       <th>14</th>
#       <th>15</th>
#       <th>16</th>
#       <th>17</th>
#       <th>18</th>
#       <th>19</th>
#       <th>20</th>
#       <th>21</th>
#       <th>22</th>
#       <th>23</th>
#     </tr>
#     <tr>
#       <th>dayofweek</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(day_hour,cmap='viridis')

# %%
# make a clustermap
# here we can see that most calls are on weekdays afternoon
# night and dawn is calm
# weekends are relatively calm
sns.clustermap(day_hour,cmap='viridis')

# %%
# Count the calls by 'month' and 'dayofweek' (at the and could choose any column)
day_month = df.groupby(by=['dayofweek','month']).count().unstack(level=-1)['e']
day_month
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>month</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>11</th>
#       <th>12</th>
#     </tr>
#     <tr>
#       <th>dayofweek</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Fri</th>
#       <td>5532</td>
#       <td>4848</td>
# ...

# %%
# make a heatmap
# new information: most calls are at winter and march
sns.heatmap(day_month,cmap='viridis')

# make a clustermap
sns.clustermap(day_month,cmap='viridis')
